# %% [markdown]
# # Time Series clustering notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data.param_data_loader2 import ParamDL2
from data.param_data_loader2 import ParamDL2Chunks, cf_failure_dict

dataset = ParamDL2()
# dataset.summarize()
clusterer = ParamDL2Chunks(dataset, cf_failure_dict, 30, 20)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)
# Processing Congestion
# Processed 24 Congestions
# Saved Congestion File
# Processing Car Following
# Processed 60 cf_events
# Saved Car Following File
# Datast Loaded. Preview of dataset:
#    driver  trip  congestion  cf_idx  type    time  gmm_n_cluster  \
# 0       1    53           0       0     0  1698.8              4
# 1       1    53           0       0     0  1698.9              4
# 2       1    53           0       0     0  1699.0              4
# 3       1    53           0       0     0  1699.1              4
# 4       1    53           0       0     0  1699.2              4
#
#    rank_0_cluster  rank_1_cluster  rank_2_cluster  ...  timeHeadway  VL_theta  \
# 0               0               3               2  ...     2.294240  0.137128
# 1               0               3               2  ...     2.304333  0.137128
# 2               0               3               2  ...     2.278744  0.138907
# 3               0               3               2  ...     2.277959  0.140121
# 4               0               3               2  ...     2.264021  0.141357
#
#    VL_dtheta  lv_speed    lv_Ax  distanceCalibrated   lv_distance  \
# 0   0.009974    5.2847  0.00000        32923.113447  32937.675447
# 1   0.009974    5.2569 -0.27800        32923.743692  32938.305692
# 2   0.009632    5.3083  0.11800        32924.372831  32938.747831
# 3   0.009801    5.2556 -0.09700        32924.996713  32939.246713
# 4   0.010598    5.1764 -0.27075        32925.618930  32939.743930
#
#    timeSinceCF  distanceSinceCF  lv_distanceSinceCF
# 0          0.0         0.000000           14.562000
# 1          0.1         0.630245           15.192245
# 2          0.2         1.259384           15.634384
# 3          0.3         1.883266           16.133266
# 4          0.4         2.505483           16.630483
#
# [5 rows x 35 columns]
# Encountered Sequence with length 0 < Required 30
# Encountered Sequence with length 0 < Required 30
# Extracted 1277 samples

# %%
clusterer.plot_elbow_method(clusterer.calculate_wcss(10))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 clusterer.plot_elbow_method(clusterer.calculate_wcss(10))
#
# File ~/Documents/Code/SURE/data/param_data_loader2.py:624, in ParamDL2Chunks.calculate_wcss(self, max_clusters)
#     622 wcss = []
#     623 for n_clusters in range(2, max_clusters + 1):
# --> 624     model = self.kmeans_dtw_cluster(n_clusters)
#     625     wcss.append(model.inertia_)
#     626 return wcss
#
# File ~/Documents/Code/SURE/data/param_data_loader2.py:615, in ParamDL2Chunks.kmeans_dtw_cluster(self, n_clusters)
#     612 def kmeans_dtw_cluster(self, n_clusters):
#     613     model = TimeSeriesKMeans(n_clusters=n_clusters, metric="dtw",
#     614                             max_iter=50, random_state=42, dtw_inertia=True)
# --> 615     model.fit(self.sampled_chunks_stacked)
#     616     return model
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/clustering/kmeans.py:821, in TimeSeriesKMeans.fit(self, X, y)
#     819     print("Init %d" % (n_successful + 1))
#     820 n_attempts += 1
# --> 821 self._fit_one_init(X_, x_squared_norms, rs)
#     822 if self.inertia_ < min_inertia:
#     823     best_correct_centroids = self.cluster_centers_.copy()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/clustering/kmeans.py:690, in TimeSeriesKMeans._fit_one_init(self, X, x_squared_norms, rs)
#     688 if self.verbose:
#     689     print("%.3f" % self.inertia_, end=" --> ")
# --> 690 self._update_centroids(X)
#     692 if numpy.abs(old_inertia - self.inertia_) < self.tol:
#     693     break
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/clustering/kmeans.py:747, in TimeSeriesKMeans._update_centroids(self, X)
#     745 for k in range(self.n_clusters):
#     746     if self.metric == "dtw":
# --> 747         self.cluster_centers_[k] = dtw_barycenter_averaging(
#     748             X=X[self.labels_ == k],
#     749             barycenter_size=None,
#     750             init_barycenter=self.cluster_centers_[k],
#     751             metric_params=metric_params,
#     752             verbose=False,
#     753         )
#     754     elif self.metric == "softdtw":
#     755         self.cluster_centers_[k] = softdtw_barycenter(
#     756             X=X[self.labels_ == k],
#     757             max_iter=self.max_iter_barycenter,
#     758             init=self.cluster_centers_[k],
#     759             **metric_params
#     760         )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/barycenters/dba.py:498, in dtw_barycenter_averaging(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose, n_init)
#     496 if verbose:
#     497     print("Attempt {}".format(i + 1))
# --> 498 bary, loss = dtw_barycenter_averaging_one_init(
#     499     X=X,
#     500     barycenter_size=barycenter_size,
#     501     init_barycenter=init_barycenter,
#     502     max_iter=max_iter,
#     503     tol=tol,
#     504     weights=weights,
#     505     metric_params=metric_params,
#     506     verbose=verbose
#     507 )
#     508 if loss < best_cost:
#     509     best_cost = loss
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/barycenters/dba.py:595, in dtw_barycenter_averaging_one_init(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose)
#     593 if verbose:
#     594     print("[DBA] epoch %d, cost: %.3f" % (it + 1, cost))
# --> 595 barycenter = _mm_update_barycenter(X_, diag_sum_v_k, list_w_k)
#     596 if abs(cost_prev - cost) < tol:
#     597     break
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/barycenters/dba.py:343, in _mm_update_barycenter(X, diag_sum_v_k, list_w_k)
#     341 sum_w_x = numpy.zeros((barycenter_size, d))
#     342 for k, (w_k, x_k) in enumerate(zip(list_w_k, X)):
# --> 343     sum_w_x += w_k.dot(x_k[:ts_size(x_k)])
#     344 barycenter = numpy.diag(1. / diag_sum_v_k).dot(sum_w_x)
#     345 return barycenter
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/utils/utils.py:445, in ts_size(ts, be)
#     404 def ts_size(ts, be=None):
#     405     """Returns actual time series size.
#     406
#     407     Final timesteps that have `NaN` values for all dimensions will be removed
#    (...)
#     443     3
#     444     """
# --> 445     be = instantiate_backend(be, ts)
#     446     ts_ = to_time_series(ts, be=be)
#     447     sz = be.shape(ts_)[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/backend/backend.py:35, in instantiate_backend(*args)
#      33     return arg
#      34 if "numpy" in f"{type(arg)}" or "numpy" in f"{arg}".lower():
# ---> 35     return Backend("numpy")
#      36 if "torch" in f"{type(arg)}" or "torch" in f"{arg}".lower():
#      37     return Backend("pytorch")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SURE/lib/python3.12/site-packages/tslearn/backend/backend.py:81, in Backend.__init__(self, data)
#      78 def __init__(self, data=None):
#      79     self.backend = select_backend(data)
# ---> 81     for element in dir(self.backend):
#      82         if "__" not in element:
#      83             setattr(self, element, getattr(self.backend, element))
#
# KeyboardInterrupt:

# %% [markdown]
# # 4 clusters it is

# %%
labels = clusterer.fit_and_plot(4)
# Out:
# There are [414, 266, 504, 93]
# (4,)
